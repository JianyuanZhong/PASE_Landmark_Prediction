# %%
import matplotlib.pyplot as plt
import torch
import torch.optim as optim
import json
import pickle as pkl
import argparse
import os, sys
import numpy as np

# %%
data_cfg = '/home/cxu-serve/u1/jzhong9/landmarkGeneration/data/oppo_all.cfg'

# %%
with open(data_cfg, "r") as cfg:
    data_cfg = json.load(cfg)

# %%
data_cfg.keys()
# Out:
# dict_keys(['train', 'dev', 'test', 'audio_root', 'landmark_root', 'mfcc_root'])

# %%
landmark_cfg = data_cfg['train']['landmark']
landmark_root = data_cfg['landmark_root']

# %%
landmark_cfg[:5]
# Out:
# ['s7/bbie4p_lmarks.npy',
#  's7/lbaq1a_lmarks.npy',
#  's7/lgwf6n_lmarks.npy',
#  's7/bgbg8n_lmarks.npy',
#  's7/pbwi9a_lmarks.npy']

# %%
landmarks = []
for landmark in landmark_cfg:
    landmarks.append(np.load(os.path.join(landmark_root, landmark)))

# %%
len(landmarks)
# Out:
# 30642

# %%
landmarks = np.asarray(landmarks).reshape(landmarks.shape[0]*landmarks.shape[1],landmarks.shape[2],landmarks.shape[3])

# %%
landmarks.shape
# Out:
# (2298150, 68, 2)

# %%
max_val = np.max(landmarks, 0)
min_val = np.min(landmarks, 0)

# %%
max_val.shape
# Out:
# (68, 2)

# %%
import seaborn as sns

# %%
ax = sns.boxplot(data=landmarks[:,:,0])

# %%
ax = sns.boxplot(data=landmarks[:,:,1])

# %%
landmarks_norm=(landmarks - min_val) / (max_val - min_val)

# %%
ax = sns.boxplot(data=landmarks_norm[:,:,0])

# %%
ax = sns.boxplot(data=landmarks_norm[:,:,1])

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
def vis(lists): # a list [frame, landmark, frame, landmark]
        windows = len(lists)
        print (windows)
        fig = plt.figure(figsize=plt.figaspect(.5))

        for i in range(windows):
    #     img  = io.imread(img_path)
            preds = lists[i]
            ax = fig.add_subplot(1, windows, i)
            ax.imshow(lists[i* 2])
            ax.plot(preds[0:17,0],preds[0:17,1],marker='o',markersize=1,linestyle='-',color='b',lw=1)
            ax.plot(preds[17:22,0],preds[17:22,1],marker='o',markersize=1,linestyle='-',color='b',lw=1)
            ax.plot(preds[22:27,0],preds[22:27,1],marker='o',markersize=1,linestyle='-',color='b',lw=1)
            ax.plot(preds[27:31,0],preds[27:31,1],marker='o',markersize=1,linestyle='-',color='b',lw=1)
            ax.plot(preds[31:36,0],preds[31:36,1],marker='o',markersize=1,linestyle='-',color='b',lw=1)
            ax.plot(preds[36:42,0],preds[36:42,1],marker='o',markersize=1,linestyle='-',color='b',lw=1)
            ax.plot(preds[42:48,0],preds[42:48,1],marker='o',markersize=1,linestyle='-',color='b',lw=1)
            ax.plot(preds[48:60,0],preds[48:60,1],marker='o',markersize=1,linestyle='-',color='b',lw=1)
            ax.plot(preds[60:68,0],preds[60:68,1],marker='o',markersize=1,linestyle='-',color='b',lw=1)
            ax.axis('off')


            plt.show()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.plot(preds[0:17,0],preds[0:17,1], marker='o',markersize=1,linestyle='-',color='b',lw=1)
plt.plot(preds[17:22,0],preds[17:22,1], marker='o',markersize=1,linestyle='-',color='b',lw=1)
plt.plot(preds[22:27,0],preds[22:27,1], marker='o',markersize=1,linestyle='-',color='b',lw=1)
plt.plot(preds[27:31,0],preds[27:31,1], marker='o',markersize=1,linestyle='-',color='b',lw=1)
plt.plot(preds[31:36,0],preds[31:36,1], marker='o',markersize=1,linestyle='-',color='b',lw=1)
plt.plot(preds[36:42,0],preds[36:42,1], marker='o',markersize=1,linestyle='-',color='b',lw=1)
plt.plot(preds[42:48,0],preds[42:48,1], marker='o',markersize=1,linestyle='-',color='b',lw=1)
plt.plot(preds[48:60,0],preds[48:60,1], marker='o',markersize=1,linestyle='-',color='b',lw=1)
plt.plot(preds[60:68,0],preds[60:68,1], marker='o',markersize=1,linestyle='-',color='b',lw=1)

# %%
vis(landmarks[:5])
# Out:
# 5
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-102-da26cfc4a7b4> in <module>
# ----> 1 vis(landmarks[:5])
#
# <ipython-input-101-0a5de8cc3720> in vis(lists)
#      10             preds = lists[i]
#      11             ax = fig.add_subplot(1, windows, i + 1)
# ---> 12             ax.imshow(lists[i* 2])
#      13             ax.plot(preds[0:17,0],preds[0:17,1],marker='o',markersize=1,linestyle='-',color='b',lw=1)
#      14             ax.plot(preds[17:22,0],preds[17:22,1],marker='o',markersize=1,linestyle='-',color='b',lw=1)
#
# IndexError: index 6 is out of bounds for axis 0 with size 5
